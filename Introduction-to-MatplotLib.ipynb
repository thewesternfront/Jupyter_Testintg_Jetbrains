# %% [markdown]
# ## Introduction to MatplotLib

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.sphinxext.plot_directive import PlotError
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 from matplotlib.sphinxext.plot_directive import PlotError
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\sphinxext\plot_directive.py:181
#     178 import textwrap
#     179 import traceback
# --> 181 from docutils.parsers.rst import directives, Directive
#     182 from docutils.parsers.rst.directives.images import Image
#     183 import jinja2  # Sphinx dependency.
#
# ModuleNotFoundError: No module named 'docutils'

# %%
plt.plot([1,2,3,4],[1,4,9,16]);

# %%
xvals = list(range(-100,101))
yvals = np.square(xvals)
plt.plot(xvals, yvals)
plt.show()

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 125, 300]);

# %% [markdown]
# ## Anatomy of a Matplot Lib Figure

# %% [markdown]
#  ![](IMG_3795.jpg)

# %% [markdown]
# ## MatplotLib Example Workflow

# %%
# 1 Import MaoplotLib
import matplotlib.pyplot as plt
# 2 prepare data x=[], y=[]
# 3 Set up the plot
fig, ax = plt.subplots(figsize = (10, 5))  # width, height, this is the aspect ratio, 5,10 is portrait, 10,5 is landscape
# 4 plot data
ax.plot(x, y)
# 5 Customize Plot
ax.set(title = "simple plot", xlabel = "x axis", ylabel = "y axis")
# 6 Save & Show
fig.savefig("sampleplot.png")

# %% [markdown]
# ## Create some plots:
# * Line Plot
# * Scatter Plot
# * Bar Plot
# * Histogram
# * Subplots

# %%
# Create some data
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 100)
print(x[:10])
# Out:
# [0.         0.1010101  0.2020202  0.3030303  0.4040404  0.50505051
#  0.60606061 0.70707071 0.80808081 0.90909091]

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2)

# %% [markdown]
# ## Use same data to make a Scatter Plot

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# Create another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
# Create a plot from a Dictionary
nut_butter_prices = {'peanut': 10, 'cashew': 14, 'almond': 8}
fig, ax = plt.subplots()
#ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
key = nut_butter_prices.keys()
val =  nut_butter_prices.values()
ax.bar(key, val)
ax.set(title = "Troy's Nut Butter Store", ylabel = "Price ($USD)");
